# %%
# Cell 1 — mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2 (redo) — verify it now
FOLDER_PATH = "/content/drive/MyDrive/30393475 (1)"
# !find "{FOLDER_PATH}" -type f | wc -l
# Out:
# 0

# %%
# !pip install -U huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.9/842.9 kB 21.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.29.0
#     Uninstalling huggingface_hub-1.29.0:
#       Successfully uninstalled huggingface_hub-1.29.0
# ...

# %%
# Cell 4 — authenticate (opens a token input box, paste your write-scoped token)
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>XTG5-S31X</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Doc2Be</b> (token: <code>oauth-Doc2Be</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
FOLDER_PATH = "/content/drive/MyDrive/30393475 (1)"
REPO_ID = "AIGeeksGroup/DiffuEx-Data"  # still confirm hyphen vs underscore

import os
total_files, total_bytes = 0, 0
for root, _, files in os.walk(FOLDER_PATH):
    for f in files:
        total_files += 1
        total_bytes += os.path.getsize(os.path.join(root, f))

print(f"{total_files} files, {total_bytes / 1e9:.2f} GB")
# Out:
# 12 files, 6.74 GB

# %%
# Check what you're actually looking at
import os
for root, _, files in os.walk(FOLDER_PATH):
    for f in files:
        print(os.path.join(root, f), f"{os.path.getsize(os.path.join(root, f)) / 1e6:.1f} MB")
# Out:
# /content/drive/MyDrive/30393475 (1)/MS_100_model_input.rar 235.1 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_registered.rar 596.3 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_preprocessed.rar 710.7 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_full.part1.rar 1073.7 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_full.part2.rar 1073.7 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_full.part3.rar 345.6 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_nifti.part1.rar 1073.7 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_nifti.part2.rar 1073.7 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_nifti.part3.rar 362.0 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_masks.rar 4.4 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_gifs.part1.rar 104.9 MB
# /content/drive/MyDrive/30393475 (1)/MS_100_patient_gifs.part2.rar 89.7 MB

# %%
REPO_ID = "AIGeeksGroup/DiffuEx_Data"

# %%
from huggingface_hub import HfApi

api = HfApi()
api.upload_folder(
    repo_id=REPO_ID,
    repo_type="dataset",
    folder_path=FOLDER_PATH,
    path_in_repo="MS3SEG",
)

print("Done. Check:", f"https://huggingface.co/datasets/{REPO_ID}/tree/main/MS3SEG")
# Out:
# Done. Check: https://huggingface.co/datasets/AIGeeksGroup/DiffuEx_Data/tree/main/MS3SEG
